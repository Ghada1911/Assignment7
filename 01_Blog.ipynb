# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghada1911/Assignment7/blob/main/01_Blog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Describition of idea

# %% [markdown]
# It streams live tweets from Twitter against a hashtag, performs sentiment analysis on each tweet, and calculates the rolling mean of sentiments. This sentiment mean is continuously sent to connected browser clients and displayed in a sparkline graph.

# %% [markdown]
# # Project Parts

# %% [markdown]
# ## 1. Web server

# %% [markdown]
# Tweets are pushed into Kafka. A sentiment analyzer picks tweets from kafka, performs sentiment analysis using NLTK and pushes the result back in Kafka.

# %% [markdown]
# ##2. Kafka

# %% [markdown]
# Kafka acts as a message broker between different modules running within the web server as well as between web server and spark streaming server.

# %% [markdown]
# ##3. Calculating rolling mean of sentiments

# %% [markdown]
# A separate pyspark program reads sentiment from Kafka using spark streaming, calculates the rolling average using spark window operations, and writes the results back to Kafka.

# %% [markdown]
# # Output ![Screenshot (168).png](data:image/png;base64,...)

# %% [markdown]
# Error when streaming the tweets because of kafka as it is unhealthy connenction when used package called kafka-python .
